# %%
import pandas as pd
# from 1_home import df_data

# %%
df_data1 = pd.read_csv(r'C:\Users\RAYSON\4_Streamlit_Game_Dados_Fifa\datasets\CLEAN_FIFA23_official_data.csv')
# for item in df_data1.columns:
#     print(item)

# %%
df_data1

filtro_ronaldo = df_data1[df_data1['Name'].str.contains('Ronaldo', case=False, na=False)]
filtro_ronaldo
# Out:
#       Unnamed: 0      ID               Name  Age  \
# 100          100   20801  Cristiano Ronaldo   37
# 256          256  230481    Ronaldo Cabrais   30
# 1843        1843  233943     Ronaldo Vieira   23
# 4191        4191   37576         11 Ronaldo   33
# 8176        8176  269489      Fábio Ronaldo   21
#
#                                                  Photo Nationality  \
# 100   https://cdn.sofifa.net/players/020/801/23_60.png    Portugal
# 256   https://cdn.sofifa.net/players/230/481/23_60.png      Brazil
# 1843  https://cdn.sofifa.net/players/233/943/23_60.png     England
# 4191  https://cdn.sofifa.net/players/037/576/11_60.png      Brazil
# 8176  https://cdn.sofifa.net/players/269/489/23_60.png    Portugal
#
#                                          Flag  Overall  Potential  \
# 100       https://cdn.sofifa.net/flags/pt.png       90         90
# 256       https://cdn.sofifa.net/flags/br.png       83         83
# ...

# %%
df_data1.head(5)
# Out:
#    Unnamed: 0      ID             Name  Age  \
# 0           0  209658      L. Goretzka   27
# 1           1  212198  Bruno Fernandes   27
# 2           2  224334         M. Acuña   30
# 3           3  192985     K. De Bruyne   31
# 4           4  224232       N. Barella   25
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.net/players/209/658/23_60.png     Germany
# 1  https://cdn.sofifa.net/players/212/198/23_60.png    Portugal
# 2  https://cdn.sofifa.net/players/224/334/23_60.png   Argentina
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 4  https://cdn.sofifa.net/players/224/232/23_60.png       Italy
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.net/flags/de.png       87         88  FC Bayern München
# 1  https://cdn.sofifa.net/flags/pt.png       86         87  Manchester United
# ...
